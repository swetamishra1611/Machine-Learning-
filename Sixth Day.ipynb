# %% [markdown]
# ### pands interpolate()

# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\RAJIV\\Desktop\\NIELIT_PATNA\\ds_salaries.csv')
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 0       80000.0             EUR        85847.0                 ES
# 1           NaN             USD            NaN                 US
# 2           NaN             USD        25500.0                 US
# 3           NaN             USD            NaN                 CA
# 4      120000.0             USD       120000.0                 CA
# ...         ...             ...            ...                ...
# 3750   412000.0             USD       412000.0                 US
# 3751   151000.0             USD       151000.0                 US
# 3752   105000.0             USD       105000.0                 US
# 3753   100000.0             USD       100000.0                 US
# 3754  7000000.0             INR        94665.0                 IN
#
#       remote_ratio company_location company_size
# 0            100.0               ES            L
# 1              NaN               US            S
# 2              NaN               US            S
# 3            100.0               CA            M
# 4            100.0               CA            M
# ...            ...              ...          ...
# 3750         100.0               US            L
# 3751         100.0               US            L
# 3752         100.0               US            S
# 3753         100.0               US            L
# 3754          50.0               IN            L
#
# [3755 rows x 11 columns]

# %%
df.interpolate()
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 0       80000.0             EUR        85847.0                 ES
# 1       90000.0             USD        55673.5                 US
# 2      100000.0             USD        25500.0                 US
# 3      110000.0             USD        72750.0                 CA
# 4      120000.0             USD       120000.0                 CA
# ...         ...             ...            ...                ...
# 3750   412000.0             USD       412000.0                 US
# 3751   151000.0             USD       151000.0                 US
# 3752   105000.0             USD       105000.0                 US
# 3753   100000.0             USD       100000.0                 US
# 3754  7000000.0             INR        94665.0                 IN
#
#       remote_ratio company_location company_size
# 0            100.0               ES            L
# 1            100.0               US            S
# 2            100.0               US            S
# 3            100.0               CA            M
# 4            100.0               CA            M
# ...            ...              ...          ...
# 3750         100.0               US            L
# 3751         100.0               US            L
# 3752         100.0               US            S
# 3753         100.0               US            L
# 3754          50.0               IN            L
#
# [3755 rows x 11 columns]

# %%
df.interpolate(method = 'linear')
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 0       80000.0             EUR        85847.0                 ES
# 1       90000.0             USD        55673.5                 US
# 2      100000.0             USD        25500.0                 US
# 3      110000.0             USD        72750.0                 CA
# 4      120000.0             USD       120000.0                 CA
# ...         ...             ...            ...                ...
# 3750   412000.0             USD       412000.0                 US
# 3751   151000.0             USD       151000.0                 US
# 3752   105000.0             USD       105000.0                 US
# 3753   100000.0             USD       100000.0                 US
# 3754  7000000.0             INR        94665.0                 IN
#
#       remote_ratio company_location company_size
# 0            100.0               ES            L
# 1            100.0               US            S
# 2            100.0               US            S
# 3            100.0               CA            M
# 4            100.0               CA            M
# ...            ...              ...          ...
# 3750         100.0               US            L
# 3751         100.0               US            L
# 3752         100.0               US            S
# 3753         100.0               US            L
# 3754          50.0               IN            L
#
# [3755 rows x 11 columns]

# %%
df.interpolate(method = 'index')
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 0       80000.0             EUR        85847.0                 ES
# 1       90000.0             USD        55673.5                 US
# 2      100000.0             USD        25500.0                 US
# 3      110000.0             USD        72750.0                 CA
# 4      120000.0             USD       120000.0                 CA
# ...         ...             ...            ...                ...
# 3750   412000.0             USD       412000.0                 US
# 3751   151000.0             USD       151000.0                 US
# 3752   105000.0             USD       105000.0                 US
# 3753   100000.0             USD       100000.0                 US
# 3754  7000000.0             INR        94665.0                 IN
#
#       remote_ratio company_location company_size
# 0            100.0               ES            L
# 1            100.0               US            S
# 2            100.0               US            S
# 3            100.0               CA            M
# 4            100.0               CA            M
# ...            ...              ...          ...
# 3750         100.0               US            L
# 3751         100.0               US            L
# 3752         100.0               US            S
# 3753         100.0               US            L
# 3754          50.0               IN            L
#
# [3755 rows x 11 columns]

# %%
df.interpolate(method = 'nearest')
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 0       80000.0             EUR        85847.0                 ES
# 1       80000.0             USD        85847.0                 US
# 2       80000.0             USD        25500.0                 US
# 3      120000.0             USD        25500.0                 CA
# 4      120000.0             USD       120000.0                 CA
# ...         ...             ...            ...                ...
# 3750   412000.0             USD       412000.0                 US
# 3751   151000.0             USD       151000.0                 US
# 3752   105000.0             USD       105000.0                 US
# 3753   100000.0             USD       100000.0                 US
# 3754  7000000.0             INR        94665.0                 IN
#
#       remote_ratio company_location company_size
# 0            100.0               ES            L
# 1            100.0               US            S
# 2            100.0               US            S
# 3            100.0               CA            M
# 4            100.0               CA            M
# ...            ...              ...          ...
# 3750         100.0               US            L
# 3751         100.0               US            L
# 3752         100.0               US            S
# 3753         100.0               US            L
# 3754          50.0               IN            L
#
# [3755 rows x 11 columns]

# %%
df.interpolate(method = 'spline',order=2)
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#             salary salary_currency  salary_in_usd employee_residence  \
# 0     8.000000e+04             EUR   85847.000000                 ES
# 1     6.889648e+03             USD   39043.488890                 US
# 2    -1.081380e+04             USD   25500.000000                 US
# 3     2.688966e+04             USD   45216.361861                 CA
# 4     1.200000e+05             USD  120000.000000                 CA
# ...            ...             ...            ...                ...
# 3750  4.120000e+05             USD  412000.000000                 US
# 3751  1.510000e+05             USD  151000.000000                 US
# 3752  1.050000e+05             USD  105000.000000                 US
# 3753  1.000000e+05             USD  100000.000000                 US
# 3754  7.000000e+06             INR   94665.000000                 IN
#
#       remote_ratio company_location company_size
# 0       100.000000               ES            L
# 1       -33.313499               US            S
# 2       -33.313262               US            S
# 3       100.000000               CA            M
# 4       100.000000               CA            M
# ...            ...              ...          ...
# 3750    100.000000               US            L
# 3751    100.000000               US            L
# 3752    100.000000               US            S
# 3753    100.000000               US            L
# 3754     50.000000               IN            L
#
# [3755 rows x 11 columns]
