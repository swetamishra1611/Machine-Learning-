# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\RAJIV\\Desktop\\NIELIT_PATNA\\ds_salaries.csv')
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.replace(to_replace='SE',value ='None')
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023             None              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023             None              FT            Data Scientist
# 4          2023             None              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020             None              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021             None              FT      Data Science Manager
#
# ...

# %%
df.replace('SE','None')
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023             None              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023             None              FT            Data Scientist
# 4          2023             None              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020             None              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021             None              FT      Data Science Manager
#
# ...

# %%
df.replace(2023,2025)
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2025               SE              FT  Principal Data Scientist
# 1          2025               MI              CT               ML Engineer
# 2          2025               MI              CT               ML Engineer
# 3          2025               SE              FT            Data Scientist
# 4          2025               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.replace([ 2023,2023,2023,2023,2023],[11,12,13,14,15])
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0            15               SE              FT  Principal Data Scientist
# 1            15               MI              CT               ML Engineer
# 2            15               MI              CT               ML Engineer
# 3            15               SE              FT            Data Scientist
# 4            15               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.replace([ 2023,2023,2023,2023,2023],0)
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0             0               SE              FT  Principal Data Scientist
# 1             0               MI              CT               ML Engineer
# 2             0               MI              CT               ML Engineer
# 3             0               SE              FT            Data Scientist
# 4             0               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.replace({'experience_level':'MI','salary_currency':'EUR'},'none')
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023             none              CT               ML Engineer
# 2          2023             none              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021             none              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.replace({'salary_currency':'[A-za-z]'},0,regex = True)
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary  salary_currency  salary_in_usd employee_residence  \
# ...

# %%
df.replace('[A-Za-z]',0,regex = True)
# Out:
#       work_year  experience_level  employment_type  job_title   salary  \
# 0          2023                 0                0          0    80000
# 1          2023                 0                0          0    30000
# 2          2023                 0                0          0    25500
# 3          2023                 0                0          0   175000
# 4          2023                 0                0          0   120000
# ...         ...               ...              ...        ...      ...
# 3750       2020                 0                0          0   412000
# 3751       2021                 0                0          0   151000
# 3752       2020                 0                0          0   105000
# 3753       2020                 0                0          0   100000
# 3754       2021                 0                0          0  7000000
#
#       salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# ...

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.replace('CT',method='ffill')
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              FT               ML Engineer
# 2          2023               MI              FT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              FT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.replace('EN',method='bfill')
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               SE              FT            Data Scientist
# 3753       2020               SE              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.replace(80000,10000,inplace=True)

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...
