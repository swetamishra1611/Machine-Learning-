# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\RAJIV\\Desktop\\NIELIT_PATNA\\ds_salaries.csv')
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 0       80000.0             EUR        85847.0                 ES
# 1           NaN             USD            NaN                 US
# 2           NaN             USD        25500.0                 US
# 3           NaN             USD            NaN                 CA
# 4      120000.0             USD       120000.0                 CA
# ...         ...             ...            ...                ...
# 3750   412000.0             USD       412000.0                 US
# 3751   151000.0             USD       151000.0                 US
# 3752   105000.0             USD       105000.0                 US
# 3753   100000.0             USD       100000.0                 US
# 3754  7000000.0             INR        94665.0                 IN
#
#       remote_ratio company_location company_size
# 0            100.0               ES            L
# 1              NaN               US            S
# 2              NaN               US            S
# 3            100.0               CA            M
# 4            100.0               CA            M
# ...            ...              ...          ...
# 3750         100.0               US            L
# 3751         100.0               US            L
# 3752         100.0               US            S
# 3753         100.0               US            L
# 3754          50.0               IN            L
#
# [3755 rows x 11 columns]

# %%
df.interpolate()
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 0       80000.0             EUR        85847.0                 ES
# 1       90000.0             USD        55673.5                 US
# 2      100000.0             USD        25500.0                 US
# 3      110000.0             USD        72750.0                 CA
# 4      120000.0             USD       120000.0                 CA
# ...         ...             ...            ...                ...
# 3750   412000.0             USD       412000.0                 US
# 3751   151000.0             USD       151000.0                 US
# 3752   105000.0             USD       105000.0                 US
# 3753   100000.0             USD       100000.0                 US
# 3754  7000000.0             INR        94665.0                 IN
#
#       remote_ratio company_location company_size
# 0            100.0               ES            L
# 1            100.0               US            S
# 2            100.0               US            S
# 3            100.0               CA            M
# 4            100.0               CA            M
# ...            ...              ...          ...
# 3750         100.0               US            L
# 3751         100.0               US            L
# 3752         100.0               US            S
# 3753         100.0               US            L
# 3754          50.0               IN            L
#
# [3755 rows x 11 columns]

# %%
df.dtypes
# Out:
# work_year               int64
# experience_level       object
# employment_type        object
# job_title              object
# salary                float64
# salary_currency        object
# salary_in_usd         float64
# employee_residence     object
# remote_ratio          float64
# company_location       object
# company_size           object
# dtype: object

# %%
df.interpolate(limit=1)
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 0       80000.0             EUR        85847.0                 ES
# 1       90000.0             USD        55673.5                 US
# 2           NaN             USD        25500.0                 US
# 3           NaN             USD        72750.0                 CA
# 4      120000.0             USD       120000.0                 CA
# ...         ...             ...            ...                ...
# 3750   412000.0             USD       412000.0                 US
# 3751   151000.0             USD       151000.0                 US
# 3752   105000.0             USD       105000.0                 US
# 3753   100000.0             USD       100000.0                 US
# 3754  7000000.0             INR        94665.0                 IN
#
#       remote_ratio company_location company_size
# 0            100.0               ES            L
# 1            100.0               US            S
# 2              NaN               US            S
# 3            100.0               CA            M
# 4            100.0               CA            M
# ...            ...              ...          ...
# 3750         100.0               US            L
# 3751         100.0               US            L
# 3752         100.0               US            S
# 3753         100.0               US            L
# 3754          50.0               IN            L
#
# [3755 rows x 11 columns]

# %%
df.interpolate(limit=2)
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 0       80000.0             EUR        85847.0                 ES
# 1       90000.0             USD        55673.5                 US
# 2      100000.0             USD        25500.0                 US
# 3           NaN             USD        72750.0                 CA
# 4      120000.0             USD       120000.0                 CA
# ...         ...             ...            ...                ...
# 3750   412000.0             USD       412000.0                 US
# 3751   151000.0             USD       151000.0                 US
# 3752   105000.0             USD       105000.0                 US
# 3753   100000.0             USD       100000.0                 US
# 3754  7000000.0             INR        94665.0                 IN
#
#       remote_ratio company_location company_size
# 0            100.0               ES            L
# 1            100.0               US            S
# 2            100.0               US            S
# 3            100.0               CA            M
# 4            100.0               CA            M
# ...            ...              ...          ...
# 3750         100.0               US            L
# 3751         100.0               US            L
# 3752         100.0               US            S
# 3753         100.0               US            L
# 3754          50.0               IN            L
#
# [3755 rows x 11 columns]

# %%
df.interpolate(limit=2,limit_direction='backward')
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 0       80000.0             EUR        85847.0                 ES
# 1           NaN             USD        55673.5                 US
# 2      100000.0             USD        25500.0                 US
# 3      110000.0             USD        72750.0                 CA
# 4      120000.0             USD       120000.0                 CA
# ...         ...             ...            ...                ...
# 3750   412000.0             USD       412000.0                 US
# 3751   151000.0             USD       151000.0                 US
# 3752   105000.0             USD       105000.0                 US
# 3753   100000.0             USD       100000.0                 US
# 3754  7000000.0             INR        94665.0                 IN
#
#       remote_ratio company_location company_size
# 0            100.0               ES            L
# 1            100.0               US            S
# 2            100.0               US            S
# 3            100.0               CA            M
# 4            100.0               CA            M
# ...            ...              ...          ...
# 3750         100.0               US            L
# 3751         100.0               US            L
# 3752         100.0               US            S
# 3753         100.0               US            L
# 3754          50.0               IN            L
#
# [3755 rows x 11 columns]

# %%
df.interpolate(limit=1,limit_direction='both')
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 0       80000.0             EUR        85847.0                 ES
# 1       90000.0             USD        55673.5                 US
# 2           NaN             USD        25500.0                 US
# 3      110000.0             USD        72750.0                 CA
# 4      120000.0             USD       120000.0                 CA
# ...         ...             ...            ...                ...
# 3750   412000.0             USD       412000.0                 US
# 3751   151000.0             USD       151000.0                 US
# 3752   105000.0             USD       105000.0                 US
# 3753   100000.0             USD       100000.0                 US
# 3754  7000000.0             INR        94665.0                 IN
#
#       remote_ratio company_location company_size
# 0            100.0               ES            L
# 1            100.0               US            S
# 2            100.0               US            S
# 3            100.0               CA            M
# 4            100.0               CA            M
# ...            ...              ...          ...
# 3750         100.0               US            L
# 3751         100.0               US            L
# 3752         100.0               US            S
# 3753         100.0               US            L
# 3754          50.0               IN            L
#
# [3755 rows x 11 columns]

# %%
df.interpolate(limit_area='inside')
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 0       80000.0             EUR        85847.0                 ES
# 1       90000.0             USD        55673.5                 US
# 2      100000.0             USD        25500.0                 US
# 3      110000.0             USD        72750.0                 CA
# 4      120000.0             USD       120000.0                 CA
# ...         ...             ...            ...                ...
# 3750   412000.0             USD       412000.0                 US
# 3751   151000.0             USD       151000.0                 US
# 3752   105000.0             USD       105000.0                 US
# 3753   100000.0             USD       100000.0                 US
# 3754  7000000.0             INR        94665.0                 IN
#
#       remote_ratio company_location company_size
# 0            100.0               ES            L
# 1            100.0               US            S
# 2            100.0               US            S
# 3            100.0               CA            M
# 4            100.0               CA            M
# ...            ...              ...          ...
# 3750         100.0               US            L
# 3751         100.0               US            L
# 3752         100.0               US            S
# 3753         100.0               US            L
# 3754          50.0               IN            L
#
# [3755 rows x 11 columns]

# %%
df.interpolate(limit_area='outside')
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 0       80000.0             EUR        85847.0                 ES
# 1           NaN             USD            NaN                 US
# 2           NaN             USD        25500.0                 US
# 3           NaN             USD            NaN                 CA
# 4      120000.0             USD       120000.0                 CA
# ...         ...             ...            ...                ...
# 3750   412000.0             USD       412000.0                 US
# 3751   151000.0             USD       151000.0                 US
# 3752   105000.0             USD       105000.0                 US
# 3753   100000.0             USD       100000.0                 US
# 3754  7000000.0             INR        94665.0                 IN
#
#       remote_ratio company_location company_size
# 0            100.0               ES            L
# 1              NaN               US            S
# 2              NaN               US            S
# 3            100.0               CA            M
# 4            100.0               CA            M
# ...            ...              ...          ...
# 3750         100.0               US            L
# 3751         100.0               US            L
# 3752         100.0               US            S
# 3753         100.0               US            L
# 3754          50.0               IN            L
#
# [3755 rows x 11 columns]

# %%
df.loc[0]
# Out:
# work_year                                 2023
# experience_level                            SE
# employment_type                             FT
# job_title             Principal Data Scientist
# salary                                 80000.0
# salary_currency                            EUR
# salary_in_usd                          85847.0
# employee_residence                          ES
# remote_ratio                             100.0
# company_location                            ES
# company_size                                 L
# Name: 0, dtype: object

# %%
df.loc[4]
# Out:
# work_year                       2023
# experience_level                  SE
# employment_type                   FT
# job_title             Data Scientist
# salary                      120000.0
# salary_currency                  USD
# salary_in_usd               120000.0
# employee_residence                CA
# remote_ratio                   100.0
# company_location                  CA
# company_size                       M
# Name: 4, dtype: object

# %%
df.loc[[0,1]]
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
#
#     salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  80000.0             EUR        85847.0                 ES         100.0
# 1      NaN             USD            NaN                 US           NaN
#
#   company_location company_size
# 0               ES            L
# 1               US            S

# %%
df.loc[[2,4]]
# Out:
#    work_year experience_level employment_type       job_title    salary  \
# 2       2023               MI              CT     ML Engineer       NaN
# 4       2023               SE              FT  Data Scientist  120000.0
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 2             USD        25500.0                 US           NaN
# 4             USD       120000.0                 CA         100.0
#
#   company_location company_size
# 2               US            S
# 4               CA            M

# %%
df.loc[2,'experience_level']
# Out:
# 'MI'

# %%
df.loc[0:3,'experience_level']
# Out:
# 0    SE
# 1    MI
# 2    MI
# 3    SE
# Name: experience_level, dtype: object

# %%
df.loc[0:2,'salary']
# Out:
# 0    80000.0
# 1        NaN
# 2        NaN
# Name: salary, dtype: float64

# %%
df.loc[df['salary']<80000.0,['experience_level']]
# Out:
#      experience_level
# 30                 SE
# 38                 MI
# 40                 EN
# 82                 MI
# 91                 SE
# ...               ...
# 3737               MI
# 3738               MI
# 3739               MI
# 3744               SE
# 3748               MI
#
# [611 rows x 1 columns]

# %%
df.iloc[0]
# Out:
# work_year                                 2023
# experience_level                            SE
# employment_type                             FT
# job_title             Principal Data Scientist
# salary                                 80000.0
# salary_currency                            EUR
# salary_in_usd                          85847.0
# employee_residence                          ES
# remote_ratio                             100.0
# company_location                            ES
# company_size                                 L
# Name: 0, dtype: object

# %%
df.iloc[[0]]
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
#
#     salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  80000.0             EUR        85847.0                 ES         100.0
#
#   company_location company_size
# 0               ES            L

# %%
df.iloc[:,0]
# Out:
# 0       2023
# 1       2023
# 2       2023
# 3       2023
# 4       2023
#         ...
# 3750    2020
# 3751    2021
# 3752    2020
# 3753    2020
# 3754    2021
# Name: work_year, Length: 3755, dtype: int64

# %%
df.iloc[[0,1]]
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
#
#     salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  80000.0             EUR        85847.0                 ES         100.0
# 1      NaN             USD            NaN                 US           NaN
#
#   company_location company_size
# 0               ES            L
# 1               US            S
